# %%
import os
import numpy as np
import pandas as pd
import re
from scipy import stats

# from utils.logger import LOGPATH

# %%
# fpath = LOGPATH.joinpath('summary-fb.csv')
fpath = '/home/nliao/code/Spectral-GNN-Benchmark/log/summary-mb.csv'
t = pd.read_csv(fpath, engine='python')

'''
fpath = '/home/nliao/code/Spectral-GNN-Benchmark/log/summary-mb-f.csv'
t2 = pd.read_csv(fpath, engine='python')

t_id = t.apply(lambda row: '+'.join((str(row['seed']), row['data'], row['model'], row['conv'])), axis=1)
t2_id = t2.apply(lambda row: '+'.join((str(row['seed']), row['data'], row['model'], row['conv'])), axis=1)
t2_id.drop_duplicates(keep='last', inplace=True)
t2 = t2.loc[t2_id.index]

row_id = []
for string in t2_id:
    match_index = t[t_id == string].index
    row_id.append(match_index[0])
t2.index = row_id
t.update(t2)
'''

t['time_learn'] = t['time_learn'] * 1000 / t['epoch_learn']
t['time_eval'] = t['time_train'] + t['time_val'] + t['time_test']
t['time_eval'] = t['time_eval'] * 1000

t['s_test'] = t.apply(lambda row: row[row['metric'] + '_test'], axis=1)
# t['zscore'] = t.groupby(['data', 'model', 'conv'])['s_test'].transform(lambda x: stats.zscore(x, ddof=0))
t['median'] = t.groupby(['data', 'model', 'conv'])['s_test'].transform('median')
t['std'] = t.groupby(['data'])['s_test'].transform('std')
outlier = t['s_test'] < t['median'] - 2 * t['std']
t[outlier]
# Out:
#       seed                data metric                    model  \
# 248     28  chameleon_filtered  s_f1i         PrecomputedFixed
# 728     21            citeseer  s_f1i           PrecomputedVar
# 731     24            citeseer  s_f1i           PrecomputedVar
# 734     27            citeseer  s_f1i           PrecomputedVar
# 736     29            citeseer  s_f1i           PrecomputedVar
# 836     26              flickr  s_f1i           PrecomputedVar
# 838     28              flickr  s_f1i           PrecomputedVar
# 900     20              flickr  s_f1i           PrecomputedVar
# 998     28  chameleon_filtered  s_f1i           PrecomputedVar
# 1057    27   squirrel_filtered  s_f1i           PrecomputedVar
# 1487    27   squirrel_filtered  s_f1i    PrecomputedVarCompose
# 1490    20   squirrel_filtered  s_f1i  PrecomputedFixedCompose
#
#                                    conv  time_pre  mem_ram_pre  mem_cuda_pre  \
# 248                    AdjConv-gaussian    0.0362        1.301         0.028
# 728                          ChebIIConv    0.5812        2.240         0.459
# 731                          ChebIIConv    0.6022        2.242         0.459
# 734                          ChebIIConv    0.6248        2.243         0.459
# 736                          ChebIIConv    0.5786        2.243         0.459
# 836                             AdjConv    0.1375        2.146         0.231
# 838                             AdjConv    0.1391        2.223         0.231
# 900                          JacobiConv    0.1825        1.901         0.000
# 998                        LegendreConv    0.0577        1.420         0.095
# 1057                           ChebConv    0.1690        1.801         0.187
# 1487          AdjConv,ChebConv,BernConv    0.7353        2.796         0.562
# 1490  AdjSkipConv,AdjSkipConv-ones,ones    0.1339        0.942         0.000
#
#       epoch_best  epoch_learn  ...  s_ap_test  s_auroc_test  s_f1i_test  \
# 248           10          500  ...     32.724        62.001      29.775
# 728          145          200  ...     26.156        59.756      29.771
# 731          190          200  ...     38.216        67.467      39.695
# 734          199          200  ...     52.676        76.747      50.076
# 736          199          200  ...     39.119        69.299      40.153
# 836            1          200  ...     20.000        50.000      11.250
# 838            1          200  ...     20.461        50.776      22.829
# 900            3          200  ...     21.234        52.138      22.961
# 998           53          200  ...     29.995        60.318      28.652
# 1057          66          200  ...     24.044        54.486      28.604
# 1487          19          200  ...     26.526        59.206      32.432
# 1490          56          200  ...     31.842        66.686      33.333
#
#       time_test  mem_ram_eval  mem_cuda_eval  time_eval  s_test   median  \
# 248      0.0003         1.301          0.028        0.9  29.775  38.7640
# 728      0.0073         2.240          0.450       22.1  29.771  72.5950
# 731      0.0074         2.242          0.450       22.4  39.695  72.5950
# 734      0.0072         2.243          0.450       22.8  50.076  72.5950
# 736      0.0073         2.243          0.450       22.1  40.153  72.5950
# 836      0.0013         2.146          0.231        4.2  11.250  33.0260
# 838      0.0011         2.223          0.231        4.6  22.829  33.0260
# 900      0.0008         1.901          0.231        3.5  22.961  33.7500
# 998      0.0012         1.420          0.095        3.6  28.652  39.3260
# 1057     0.0009         1.801          0.187        3.7  28.604  34.2340
# 1487     0.0022         2.796          0.562        7.3  32.432  38.5135
# 1490     0.0006         1.277          0.067        2.3  33.333  38.1755
#
#            std
# 248   4.254534
# 728   5.474821
# 731   5.474821
# 734   5.474821
# 736   5.474821
# 836   4.390117
# 838   4.390117
# 900   4.390117
# 998   4.254534
# 1057  2.419963
# 1487  2.419963
# 1490  2.419963
#
# [12 rows x 34 columns]

# %%
dlst = ["cora", "citeseer", "pubmed", "flickr", "chameleon_filtered", "squirrel_filtered", "actor", "roman_empire", ]
        # "amazon_ratings", "minesweeper", "tolokers", "questions", "reddit", "penn94", \
        # "ogbn-arxiv", "arxiv-year", "genius", "twitch-gamer", "ogbn-mag"]
id_cols = ["seed", 'data', 'model', 'conv',]
m_cols = ['time_pre', 'mem_ram_pre', 'time_learn', 'mem_ram_train', 'mem_cuda_train', 's_test', 'time_eval',]
conv_repr = {
    'MLP': {'Identity-impulse': 'Identity',},
    'PrecomputedFixed': {
        'AdjSkipConv-ones': 'Linear',
        'AdjConv-impulse':  'Impulse',
        'AdjConv-mono':     'Monomial',
        'AdjConv-appr':     'PPR',
        'AdjConv-hk':       'HK',
        'AdjConv-gaussian': 'Gaussian',},
    'PrecomputedVar': {
        'AdjSkipConv':      'Var-Linear',
        'AdjConv':          'Var-Monomial',
        'HornerConv':       'Horner',
        'ChebConv':         'Chebyshev',
        'ClenshawConv':     'Clenshaw',
        'ChebIIConv':       'ChebInterp',
        'BernConv':         'Bernstein',
        'LegendreConv':     'Legendre',
        'JacobiConv':       'Jacobi',
        'OptBasisConv':     'OptBasis',},
    # 'AdaGNN': {'LapiConv':  'AdaGNN',},
        # 'OptBasisConv':     'OptBasisGNN',},
    'PrecomputedFixedCompose': {
        'AdjSkipConv,AdjSkipConv-ones,ones': 'FAGNN',
        'AdjSkip2Conv,AdjSkip2Conv-gaussian,gaussian': 'G$^2$CN',
        'AdjDiffConv,AdjDiffConv-appr,appr': 'GNN-LF/HF',},
    'PrecomputedVarCompose': {
        'AdjConv,ChebConv,BernConv': 'FiGURe',}}

def reverse_name(name):
    for k, m in conv_repr.items():
        for c, n in m.items():
            if n == name:
                return k, c
    return None, None

flst = []
for m in conv_repr.values():
    for c, name in m.items():
        flst.append(name)

nil_repr = []
for row in t.itertuples():
    if row.model not in conv_repr:
        nil_repr.append(row.model)
    else:
        if row.conv not in conv_repr[row.model]:
            nil_repr.append('+'.join((row.model, row.conv)))
set(nil_repr)
# Out:
# set()

# %%
def get_df(t):
    tt = t[t['data'].isin(dlst)][id_cols+m_cols].sort_values(by=['data', 'model', 'conv', 'seed'])
    # print(tt.sort_index(ascending=False).groupby(['data', 'model', 'conv']).filter(lambda x: len(x) > 10))
    df = tt.groupby(['data', 'model', 'conv'])[m_cols].agg(['mean', 'std'])
    df.columns = ['_'.join(col).strip() for col in df.columns.values]
    df.reset_index(inplace=True)

    df['name'] = df.apply(lambda row: conv_repr[row['model']][row['conv']] if (row['model'] in conv_repr) and (row['conv'] in conv_repr[row['model']]) else None, axis=1)
    df.dropna(subset=['name'], inplace=True)
    df.drop(columns=['model', 'conv'], inplace=True)
    df = df[['data', 'name'] + df.columns.tolist()[1:-1]]
    return df

# t = t[~outlier]
df = get_df(t)
df
# Out:
#                   data      name  time_pre_mean  time_pre_std  \
# 0                actor       PPR        0.38011      0.314038
# 1                actor  Gaussian        0.08924      0.020007
# 2                actor        HK        0.11394      0.047949
# 3                actor   Impulse        0.45752      0.450204
# 4                actor  Monomial        0.11726      0.034471
# ..                 ...       ...            ...           ...
# 159  squirrel_filtered    Horner        0.12937      0.016261
# 160  squirrel_filtered    Jacobi        0.15543      0.020712
# 161  squirrel_filtered  Legendre        0.13262      0.008487
# 162  squirrel_filtered  OptBasis        2.28026      0.386258
# 163  squirrel_filtered    FiGURe        0.75947      0.056414
#
#      mem_ram_pre_mean  mem_ram_pre_std  time_learn_mean  time_learn_std  \
# 0              1.7189         0.260530          4.46050        0.675792
# 1              1.7967         0.274220          4.49722        0.490596
# 2              1.6106         0.221253          4.44284        0.270204
# 3              1.6936         0.266873          4.67524        0.252514
# 4              1.7299         0.245460          4.58326        0.575605
# ..                ...              ...              ...             ...
# 159            1.6958         0.158014          4.22715        0.351658
# 160            1.7987         0.207198          4.12935        0.376226
# 161            1.7870         0.161763          4.29080        0.511529
# 162            1.8252         0.180559          4.37865        0.317319
# 163            2.7229         0.176130          8.98540        0.561860
#
#      mem_ram_train_mean  mem_ram_train_std  mem_cuda_train_mean  \
# 0                1.7512           0.159422                0.040
# 1                1.8356           0.156197                0.040
# 2                1.6368           0.138631                0.040
# 3                1.7253           0.181391                0.040
# 4                1.7609           0.148057                0.040
# ..                  ...                ...                  ...
# 159              1.7209           0.082082                0.199
# 160              1.8267           0.121503                0.186
# 161              1.8047           0.107887                0.186
# 162              1.8486           0.106727                0.186
# 163              2.7229           0.176130                0.562
#
#      mem_cuda_train_std  s_test_mean  s_test_std  time_eval_mean  \
# 0              0.000000      32.4868    1.221574            1.51
# 1              0.000000      32.8421    1.279674            1.40
# 2              0.000000      32.8816    1.392876            1.54
# 3              0.000000      24.3159    1.604023            1.52
# 4              0.000000      32.6381    1.409783            1.51
# ..                  ...          ...         ...             ...
# 159            0.000000      36.6217    1.689554            5.14
# 160            0.003162      35.8559    1.801267            3.31
# 161            0.003162      36.1486    2.018017            3.35
# 162            0.003162      34.9999    1.624892            3.58
# 163            0.000000      37.6350    2.859860            6.76
#
#      time_eval_std
# 0         0.233095
# 1         0.115470
# 2         0.150555
# 3         0.220101
# 4         0.207900
# ..             ...
# 159       0.779173
# 160       0.570477
# 161       0.690008
# 162       0.666333
# 163       1.248288
#
# [164 rows x 16 columns]

# %% [markdown]
# ## Fine

# %%
# dlst_acc = dlst
dlst_acc = ["cora", "citeseer", "pubmed", "flickr", "chameleon_filtered", "squirrel_filtered", "actor", "roman_empire"]
# dlst_acc = ["cora", "citeseer", "pubmed", "flickr", "reddit", "chameleon_filtered", "squirrel_filtered", "actor", "roman_empire"]
# dlst_acc = ["ogbn-arxiv", "amazon_ratings", "minesweeper", "tolokers", "questions", "penn94", "arxiv-year", "genius", "twitch-gamer"]

acc_dual = pd.DataFrame(index=flst, columns=pd.MultiIndex.from_product([dlst_acc, ['mean', 'std']]), dtype=float)
acc_str = pd.DataFrame(index=flst, columns=dlst_acc, dtype=str)
for row in acc_str.index:
    for col in acc_str.columns:
        mean = df.loc[(df['name'] == row) & (df['data'] == col), 's_test_mean'].values
        std = df.loc[(df['name'] == row) & (df['data'] == col), 's_test_std'].values
        if len(mean) > 0:
            acc_dual.loc[row, col] = mean[0], std[0]
            acc_str.loc[row, col] = f'{mean[0]:.2f}\\tpm{{{std[0]:.2f}}}'

acc_dual.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_d2904_row0_col0, #T_d2904_row1_col15, #T_d2904_row2_col15, #T_d2904_row3_col9, #T_d2904_row3_col11, #T_d2904_row4_col7, #T_d2904_row6_col7, #T_d2904_row7_col1, #T_d2904_row9_col3, #T_d2904_row9_col6, #T_d2904_row9_col14, #T_d2904_row10_col10, #T_d2904_row11_col4, #T_d2904_row11_col13, #T_d2904_row12_col2, #T_d2904_row12_col8, #T_d2904_row17_col5, #T_d2904_row18_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d2904_row0_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_d2904_row0_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_d2904_row0_col3, #T_d2904_row2_col6, #T_d2904_row10_col5, #T_d2904_row13_col3, #T_d2904_row14_col1, #T_d2904_row15_col15, #T_d2904_row17_col15 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d2904_row0_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_d2904_row0_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_d2904_row0_col6, #T_d2904_row4_col14, #T_d2904_row5_col8, #T_d2904_row7_col12, #T_d2904_row8_col7, #T_d2904_row10_col0, #T_d2904_row10_col4, #T_d2904_row12_col1, #T_d2904_row12_col3, #T_d2904_row12_col15, #T_d2904_row14_col13, #T_d2904_row16_col5, #T_d2904_row18_col10, #T_d2904_row18_col11, #T_d2904_row20_col2, #T_d2904_row20_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d2904_row0_col7, #T_d2904_row10_col7, #T_d2904_row11_col6, #T_d2904_row17_col14, #T_d2904_row18_col7, #T_d2904_row19_col15 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d2904_row0_col8, #T_d2904_row0_col9, #T_d2904_row0_col10, #T_d2904_row0_col11, #T_d2904_row0_col12, #T_d2904_row0_col13, #T_d2904_row0_col14, #T_d2904_row0_col15 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col0 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_d2904_row1_col2, #T_d2904_row3_col2, #T_d2904_row16_col4, #T_d2904_row19_col12 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col3, #T_d2904_row2_col3, #T_d2904_row11_col15, #T_d2904_row14_col3, #T_d2904_row17_col3, #T_d2904_row18_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d2904_row1_col4, #T_d2904_row15_col13 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col5, #T_d2904_row2_col1, #T_d2904_row8_col10 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d2904_row1_col6, #T_d2904_row18_col15 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d2904_row1_col7, #T_d2904_row3_col15, #T_d2904_row7_col3, #T_d2904_row8_col3, #T_d2904_row13_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_d2904_row1_col8, #T_d2904_row16_col0, #T_d2904_row16_col8, #T_d2904_row20_col10 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col9 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col10, #T_d2904_row6_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col11, #T_d2904_row15_col8 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_d2904_row1_col12, #T_d2904_row8_col13 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_d2904_row1_col13, #T_d2904_row13_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_d2904_row1_col14 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_d2904_row2_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_d2904_row2_col2, #T_d2904_row20_col12 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_d2904_row2_col4, #T_d2904_row10_col6 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_d2904_row2_col5, #T_d2904_row11_col10, #T_d2904_row18_col5 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_d2904_row2_col7, #T_d2904_row5_col3, #T_d2904_row11_col3, #T_d2904_row14_col5 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d2904_row2_col8 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_d2904_row2_col9, #T_d2904_row10_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d2904_row2_col10, #T_d2904_row8_col2, #T_d2904_row15_col14, #T_d2904_row19_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_d2904_row2_col11 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_d2904_row2_col12, #T_d2904_row3_col1, #T_d2904_row19_col10 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_d2904_row2_col13 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_d2904_row2_col14, #T_d2904_row12_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_d2904_row3_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_d2904_row3_col3, #T_d2904_row6_col0, #T_d2904_row7_col7, #T_d2904_row15_col5, #T_d2904_row19_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_d2904_row3_col4, #T_d2904_row10_col14, #T_d2904_row11_col5 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d2904_row3_col5, #T_d2904_row3_col10 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_d2904_row3_col6 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_d2904_row3_col7, #T_d2904_row16_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d2904_row3_col8, #T_d2904_row14_col8 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_d2904_row3_col12, #T_d2904_row17_col10 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_d2904_row3_col13 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_d2904_row3_col14 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col0, #T_d2904_row14_col2, #T_d2904_row15_col0, #T_d2904_row20_col0, #T_d2904_row20_col11 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_d2904_row4_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col3, #T_d2904_row14_col15 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d2904_row4_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col5, #T_d2904_row4_col10, #T_d2904_row9_col1, #T_d2904_row9_col5 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_d2904_row4_col6 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col8, #T_d2904_row14_col14 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col9, #T_d2904_row6_col13 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_d2904_row4_col11, #T_d2904_row11_col9 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_d2904_row4_col12 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_d2904_row4_col13, #T_d2904_row12_col13 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d2904_row4_col15, #T_d2904_row12_col7, #T_d2904_row19_col3, #T_d2904_row20_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_d2904_row5_col0, #T_d2904_row7_col6, #T_d2904_row9_col0, #T_d2904_row10_col2 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col1, #T_d2904_row5_col5 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_d2904_row5_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col4, #T_d2904_row6_col14, #T_d2904_row17_col0, #T_d2904_row19_col2 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col6, #T_d2904_row6_col8 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col7, #T_d2904_row16_col15, #T_d2904_row17_col1, #T_d2904_row20_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_d2904_row5_col9 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col10, #T_d2904_row17_col13 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col11, #T_d2904_row10_col13 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col12, #T_d2904_row6_col12, #T_d2904_row19_col6 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col13 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_d2904_row5_col14, #T_d2904_row8_col4, #T_d2904_row14_col4 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_d2904_row5_col15, #T_d2904_row10_col3, #T_d2904_row18_col14 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d2904_row6_col1, #T_d2904_row9_col9 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_d2904_row6_col3, #T_d2904_row7_col15, #T_d2904_row15_col3, #T_d2904
